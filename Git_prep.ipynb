# %% [markdown]
# ## Git branch
# Source: [basic-git-branching](https://git-scm.com/book/en/v2/Git-Branching-Basic-Branching-and-Merging), [how-to-use-branches](https://www.atlassian.com/git/tutorials/using-branches), [branching-in-a-nutshell](https://git-scm.com/book/en/v2/Git-Branching-Branches-in-a-Nutshell)
#
# ### Why use branches?
# * **Branches** are individual versions of a repository. They are just lightweight **movable pointers to commits**. When you create a branch, you create a new pointer. The default branch name in Git is main (a.k.a master). As you start making commits, you're given a main branch that points to the last commit you made. Every time you commit, the main branch pointer moves forward automatically.
#
# * **Branching** means you *diverge from the main line* (main branch) of development and *continue to do work without messing with that main line* (in feature branch). Branches allow you to develop new features, fix bugs, or safely experiment with new ideas in a contained area of your repository. You can also **merge and switch between branches as just fast**.
#
# ### How to use branch?
# 1. You always create a branch from an existing branch (main). Typically, you might create a new branch (Collab1) from the default branch of your repository.
# <center><img width="300" height="300" src="branch1.png"></center>
#
# 2. You can then work on this new branch in isolation from changes that other people are making to the repository and in parallel with others in that repository.
#
# <center><img width="500" height="500" src="branch2.png"></center>
#
# 3. You can check the branches in your repository (Assignment_SPW) using **`git branch`**. The current branch you are in is denoted with **`*`**. Each branch should serve a development purpose, such as fixing, develop new feature, ect.
#
# <center><img width="500" height="500" src="branch_all.png"></center>

# %% [markdown]
# ## Git rebase
#
# ###
